# %% [markdown]
# # 1. Importation de Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # 2. Chargement de données

# %%
# Chargement de données
data = pd.read_csv("../data/Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# # 3 Exploration de données

# %%
# Verification de la dimension : ligne et Colonnes
data.shape
# Out:
# (30, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#verifaction de données manquante
data.isnull()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# # 4 Division de données en Variable Independante et Dependante

# %%
# variable independante
X = data.iloc[:, :-1].values

# variable dependante
y = data.iloc[:, -1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %% [markdown]
# # 5 Sepration de données Train data & Test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
#affichage de dimension
print("X train :", X_train.shape)
print("X train :", y_train.shape)
# Out:
# X train : (24, 1)
# X train : (24,)

# %%
print("X train :", X_test.shape)
print("X train :", y_test.shape)
# Out:
# X train : (6, 1)
# X train : (6,)

# %% [markdown]
# # 6 Création du modele

# %% [markdown]
# ## 6.1 Linear Regression : Regression Lineaire

# %%
# création du modele
model_Lineaire =  LinearRegression()

# %%
# Entrainement du modele
model_Lineaire.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Faire la prédiction
y_test
# Out:
# array([ 67938., 122391., 116969.,  63218., 109431.,  39343.])

# %%
y_predicted_lr = model_Lineaire.predict(X_test)
y_predicted_lr
# Out:
# array([ 72023.51967848, 123221.12252239, 115636.29247144,  62542.48211479,
#        108051.46242049,  35995.57693647])

# %%
mean_squared_error(y_test, y_predicted_lr)
# Out:
# 5453562.21914827

# %%
r2_score(y_test, y_predicted_lr)
# Out:
# 0.9944092048209745

# %%
print("Mean Squared Error :", mean_squared_error(y_test, y_predicted_lr))
print("R2_Score :", r2_score(y_test, y_predicted_lr))
# Out:
# Mean Squared Error : 5453562.21914827
# R2_Score : 0.9944092048209745

# %% [markdown]
# # Visualition de la prediction

# %%
plt.scatter(X_train, y_train, color='red', label="Training Data") # Train Data
plt.scatter(X_test, y_test, color = "Green", label="Test Data")
plt.plot(X_train, model_Lineaire.predict(X_train), color='blue', label="Score predite")
plt.xlabel("Heure Etude")
plt.ylabel("Score")
plt.title("Regression Lineaire sur les données d'entrainement")
plt.legend()
plt.show()

# %%
plt.scatter(X_test, y_test, color='red',  label="Test Data") # Test Data
plt.plot(X_test, model_Lineaire.predict(X_test), color='blue', label="Score predite")
plt.xlabel("Heure Etude")
plt.ylabel("Score")
plt.title("Regression Lineaire sur les données d'entrainement")
plt.legend()
plt.show()

# %% [markdown]
# ### Faire une simple Prediction

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
model_Lineaire.predict([[1.4]])
# Out:
# array([38839.88820557])

# %%
model_Lineaire.predict([[2.9]])
# Out:
# array([53061.4445511])

# %% [markdown]
# ## 6.2 Random Forest

# %%
model_Random_Forest = RandomForestRegressor()
model_Random_Forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_predicted_rf = model_Random_Forest.predict(X_test)

# %%
print("Mean Squard Error de Random Forest :", mean_squared_error(y_test, y_predicted_rf))
print("R2_score de Random Forest :", r2_score(y_test, y_predicted_rf))
# Out:
# Mean Squard Error de Random Forest : 19117389.18601049
# R2_score de Random Forest : 0.9804015425144642
